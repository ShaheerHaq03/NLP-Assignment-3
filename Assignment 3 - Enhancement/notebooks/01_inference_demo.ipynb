# %% [markdown]
# # NLI Enhancement Experiment Inference Demo\nRun this after installing requirements. For a trained model, set `model_dir` to your saved checkpoint folder.\n

# %%
import sys\nsys.path.append('..')\nfrom inference import predict\n

# %%
premise = 'Amina submitted the report before the deadline.'\nhypothesis = 'Amina submitted something before the deadline.'\nmodel_dir = 't5-small'  # replace with checkpoints/<your_model>/model after training with save_models=True\npredict(premise, hypothesis, model_dir=model_dir, profile='smoke')\n
